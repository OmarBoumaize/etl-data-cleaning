# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgresql://postgres:0000@localhost:5432/ISIL')
data = pd.read_csv('/content/merged_data.csv' ,dtype={'telephone' :str })
# Out:
# <ipython-input-76-87b58cb71d87>:4: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/merged_data.csv' ,dtype={'telephone' :str })

# %%
data.columns
data['adresse'].dropna()
# Out:
# 1                                 LA LAGUNE
# 10              ZAOUIT BEN HMIDA  ESSAOUIRA
# 21                                209 lot 5
# 22        119 bloc c lot al amani essaouira
# 37                            CARTE PATIENT
#                         ...
# 103651                            PERE TAIB
# 103654               MERE :wissam benzoubir
# 103655                                 LOT5
# 103666     fille khadija el aloui maternite
# 103672                                fils
# Name: adresse, Length: 18566, dtype: object

# %%
data = data.rename(columns={
    'Chun': 'id',
    'adresse1': 'nom',
    'cin' : 'cin' ,
    'dateheure' : 'date_creation' ,
    'dnaiss' : 'date_naissance'  ,
     'telephone' : 'tel' ,
    'sit' : 'civilite' ,
    'total_comment' : 'commentaire' ,
    'ref' : 'ref' ,
    'id' : 'medecin_id' ,
    'Groupe' : 'gs' ,
    'determine1' : 'date_determ1' ,
    'detrmine2' :  'date_determ2' ,
     'Rhesus'  : 'rhesus' ,
      'ba' : 'sexe' ,
      'ref' : 'ipp' ,
    'Vignette' : 'groupe_sanguin' ,
    'adresse' : 'adresse1'




    # add all mappings
})

# %%
data.columns
# Out:
# Index(['id', 'nom', 'prenom', 'adresse1', 'region', 'cin', 'date_creation',
#        'date_naissance', 'email', 'sexe', 'tel', 'civilite', 'ipp', 'age',
#        'commentaire', 'medecin_nom', 'medecin_id', 'gs', 'date_determ1',
#        'determine2', 'id_groupage', 'rhesus', 'groupe_sanguin'],
#       dtype='object')

# %%
data = data.drop(columns= ['medecin_nom' ,'id_groupage', 'age' , ])
data.columns
# Out:
# Index(['id', 'nom', 'prenom', 'adresse1', 'region', 'cin', 'date_creation',
#        'date_naissance', 'email', 'sexe', 'tel', 'civilite', 'ipp',
#        'commentaire', 'medecin_id', 'gs', 'date_determ1', 'determine2',
#        'rhesus', 'groupe_sanguin'],
#       dtype='object')

# %%
target_cols = [
    'id', 'adresse1', 'adresse2', 'cin', 'code_postal', 'date_creation',
    'date_modification', 'date_naissance', 'email', 'fax', 'fixe',
    'nom', 'prenom', 'sexe', 'tel', 'username', 'ville', 'champsde_transmission',
    'civilite', 'commentaire', 'ipp', 'mode_transmission', 'nom_jeune_fille',
    'solde', 'canal_transmission_id', 'medecin_id', 'path_cin', 'gs',
    'date_determ1', 'date_determ2', 'num_determ', 'ref_determ1', 'ref_determ2',
    'rhesus', 'autre_identite', 'passeport', 'permis_conduire', 'titre_sejour',
    'groupe_sanguin', 'responsable_legal_id'
]

for col in target_cols:
    if col not in data.columns:
        data[col] = None  # Fill missing columns with nulls

# %%
data = data[target_cols]

# %% [markdown]
# before loading using None Instead of errors and coerce

# %%
for col in target_cols :
  data[col] = data[col].apply(lambda x : None if pd.isna(x) else x )
# Out:
# <ipython-input-83-bfa1566b14d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].apply(lambda x : None if pd.isna(x) else x )

# %%
data
# Out:
#             id   adresse1 adresse2      cin code_postal        date_creation  \
# 0            1       None     None     None        None  2014-10-31 07:37:46
# 1       242815  LA LAGUNE     None  N398248        None  2024-04-24 10:24:04
# 2           11       None     None     None        None  2014-10-31 09:12:00
# 3        74367       None     None     None        None  2016-12-05 09:14:09
# 4           13       None     None     None        None  2014-10-31 09:18:33
# ...        ...        ...      ...      ...         ...                  ...
# 103680  253077       None     None  N227862        None  2024-11-05 10:03:47
# 103681  253078       None     None  N466183        None  2024-11-05 10:07:18
# 103682  253081       None     None     None        None  2024-11-05 10:12:05
# 103683  253088       None     None  N353787        None  2024-11-05 10:27:34
# 103684  253090       None     None     None        None  2024-11-05 10:31:58
#
# ...

# %%
data.dtypes
# Out:
# id                         int64
# adresse1                  object
# adresse2                  object
# cin                       object
# code_postal               object
# date_creation             object
# date_modification         object
# date_naissance            object
# email                      int64
# fax                       object
# fixe                      object
# nom                       object
# prenom                    object
# sexe                      object
# tel                       object
# username                  object
# ville                     object
# champsde_transmission     object
# civilite                  object
# commentaire               object
# ipp                       object
# mode_transmission         object
# nom_jeune_fille           object
# solde                     object
# canal_transmission_id     object
# medecin_id               float64
# path_cin                  object
# gs                        object
# ...

# %%
data.to_csv('data_integration.csv' , index=False)

# %%
#data.to_sql('patient', engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144             try:
# --> 145                 self._dbapi_connection = engine.raw_connection()
#     146             except dialect.loaded_dbapi.Error as err:
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in raw_connection(self)
#    3296         """
# -> 3297         return self.pool.connect()
#    3298
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     448         """
# --> 449         return _ConnectionFairy._checkout(self)
#     450
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#    1263         if not fairy:
# ...

# %%
grouapge = pd.read_excel('/content/export_groupages.xlsx')

# %%
grouapge.iloc[: , 15:25]
# Out:
#        Rhesus2  Phenotype2 sexe  Aff_Groupe  Vignette2  Rq1  Rq2  Rq3  Rq4
# 0          NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 1          NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 2          NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 3          NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 4          NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# ...        ...         ...  ...         ...        ...  ...  ...  ...  ...
# 13309      NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 13310      NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 13311      NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 13312      NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
# 13313      NaN         NaN    F           1        NaN  NaN  NaN  NaN  NaN
#
# [13314 rows x 9 columns]
